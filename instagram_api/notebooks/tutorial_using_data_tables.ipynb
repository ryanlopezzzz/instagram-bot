# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
instagram_api_folder = os.path.dirname(os.getcwd())

# %% [markdown]
# # Loading data tables

# %%
#This is the username of the account that collected the data
api_username = 'cuteanimalzzzz123'

# %%
user_table_filename = os.path.join(instagram_api_folder,'saved_info/%s_collected_user_info_table.csv'%api_username)
if os.path.isfile(user_table_filename):
    loaded_user_table = pd.read_csv(user_table_filename, index_col=0)
else:
    loaded_user_table = None

# %%
loaded_user_table
# Out:
#                       username  private_status  follower_count  \
# user_id
# 9226952833              khadhs           False              43
# 6797344609       vanessa_mrz._           False             240
# 5200802500         sv_sunching           False              73
# 43466147776     arif_can_16_34           False            1254
# 7714004987             396.071           False              11
# ...                        ...             ...             ...
# 4120079014    jamieroberts6222            True             568
# 39612202963        carconnell_           False             419
# 48740245931  jameshatesjameson            True             265
# 8478000530       luca.scharrer           False              47
# 50004795460  cuteanimalzzzz123           False               0
#
#              following_count  media_count          full_name  \
# user_id
# 9226952833               620            9                NaN
# 6797344609              1959           16             🅅🄰🄽🄸🄸💗
# 5200802500               159            6        sv_sunching
# 43466147776             3342           57  Arif Muhammad Can
# 7714004987                83            2            071 396
# ...                      ...          ...                ...
# 4120079014              1943           87      Jamie Roberts
# 39612202963              582            0   Carley Elizabeth
# 48740245931             1578           26              James
# 8478000530                41            2      Luca Scharrer
# 50004795460                2            1       Cute Animals
#
#                                                profile_pic_url  \
# user_id
# 9226952833   https://scontent-lax3-1.cdninstagram.com/v/t51...
# 6797344609   https://scontent-lax3-2.cdninstagram.com/v/t51...
# 5200802500   https://scontent-lax3-2.cdninstagram.com/v/t51...
# 43466147776  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 7714004987   https://instagram.fsac1-2.fna.fbcdn.net/v/t51....
# ...                                                        ...
# 4120079014   https://scontent-lax3-1.cdninstagram.com/v/t51...
# 39612202963  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 48740245931  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 8478000530   https://scontent-lax3-2.cdninstagram.com/v/t51...
# 50004795460  https://scontent-lax3-2.cdninstagram.com/v/t51...
#
#                                                       bio_text url_in_bio  \
# user_id
# 9226952833                                                 NaN        NaN
# 6797344609                      https://tellonym.me/vaniii_rgb        NaN
# 5200802500                                                 NaN        NaN
# 43466147776  🖤الدنيـــه توجــع😩 .🖤لو رحـل 💔عنــك 😓عزيز ..😔\...        NaN
# 7714004987                                                 NaN        NaN
# ...                                                        ...        ...
# 4120079014                           Senior RHS class of 2022.        NaN
# 39612202963                                                NaN        NaN
# 48740245931                       spam, love following people.        NaN
# 8478000530   4th year CCS physics student at UCSB. Interest...        NaN
# 50004795460                       I post cute animal photos! 🥰        NaN
#
#              hashtag_following_count  usertags_count  api_request_time
# user_id
# 9226952833                         1               2      1.640588e+09
# 6797344609                        21              73      1.640588e+09
# 5200802500                         0              10      1.640588e+09
# 43466147776                        0               1      1.640588e+09
# 7714004987                         2               1      1.640588e+09
# ...                              ...             ...               ...
# 4120079014                         1               0      1.639391e+09
# 39612202963                        0               1      1.639391e+09
# 48740245931                        0               0      1.639391e+09
# 8478000530                         1              12      1.639386e+09
# 50004795460                        0               0      1.639386e+09
#
# [8408 rows x 12 columns]

# %%
media_table_filename = os.path.join(instagram_api_folder,'saved_info/%s_collected_media_info_table.csv'%api_username)
if os.path.isfile(media_table_filename):
    loaded_media_table = pd.read_csv(media_table_filename, index_col=0)
else:
    loaded_media_table = None

# %%
loaded_media_table
# Out:
#                                    user_id         username  like_count  \
# media_id
# 2693128601193149827_8553571503  8553571503  bennhilataoufik           4
# 2599511443779455263_8553571503  8553571503  bennhilataoufik           5
# 2689675390889225759_8553571503  8553571503  bennhilataoufik           2
# 2043235208842284268_8553571503  8553571503  bennhilataoufik          15
# 2060257853995512713_8553571503  8553571503  bennhilataoufik          11
# ...                                    ...              ...         ...
# 1918248265532065779_9226952833  9226952833           khadhs          36
# 1915307431740546250_9226952833  9226952833           khadhs          23
# 1915309868421262314_9226952833  9226952833           khadhs          34
# 1915478755821552984_9226952833  9226952833           khadhs          36
# 1913322824232427084_9226952833  9226952833           khadhs          35
#
#                                 comment_count  time_posted  \
# media_id
# 2693128601193149827_8553571503              0   1635265968
# 2599511443779455263_8553571503              0   1624105969
# 2689675390889225759_8553571503              1   1634854314
# 2043235208842284268_8553571503              4   1557792639
# 2060257853995512713_8553571503              1   1559821896
# ...                                       ...          ...
# 1918248265532065779_9226952833              2   1542893034
# 1915307431740546250_9226952833              0   1542542476
# 1915309868421262314_9226952833              0   1542542756
# 1915478755821552984_9226952833              2   1542562890
# 1913322824232427084_9226952833              0   1542305876
#
#                                 num_sliding_content  media_type caption_text  \
# media_id
# 2693128601193149827_8553571503                    1           1          NaN
# 2599511443779455263_8553571503                    1           2          NaN
# 2689675390889225759_8553571503                    1           1          NaN
# 2043235208842284268_8553571503                    1           1     هانا جيت
# 2060257853995512713_8553571503                    1           1          NaN
# ...                                             ...         ...          ...
# 1918248265532065779_9226952833                    1           1          NaN
# 1915307431740546250_9226952833                    1           2          NaN
# 1915309868421262314_9226952833                    1           2          NaN
# 1915478755821552984_9226952833                    1           2          NaN
# 1913322824232427084_9226952833                    1           1          NaN
#
#                                                                        media_urls  \
# media_id
# 2693128601193149827_8553571503  ['https://scontent-sjc3-1.cdninstagram.com/v/t...
# 2599511443779455263_8553571503  ['https://scontent-sjc3-1.cdninstagram.com/v/t...
# 2689675390889225759_8553571503  ['https://scontent-sjc3-1.cdninstagram.com/v/t...
# 2043235208842284268_8553571503  ['https://scontent-sjc3-1.cdninstagram.com/v/t...
# 2060257853995512713_8553571503  ['https://scontent-sjc3-1.cdninstagram.com/v/t...
# ...                                                                           ...
# 1918248265532065779_9226952833  ['https://scontent-sjc3-1.cdninstagram.com/v/t...
# 1915307431740546250_9226952833  ['https://scontent-sjc3-1.cdninstagram.com/v/t...
# 1915309868421262314_9226952833  ['https://scontent-sjc3-1.cdninstagram.com/v/t...
# 1915478755821552984_9226952833  ['https://scontent-sjc3-1.cdninstagram.com/v/t...
# 1913322824232427084_9226952833  ['https://scontent-sjc3-1.cdninstagram.com/v/t...
#
#                                tagged_users  api_request_time
# media_id
# 2693128601193149827_8553571503          NaN      1.641868e+09
# 2599511443779455263_8553571503          NaN      1.641868e+09
# 2689675390889225759_8553571503          NaN      1.641868e+09
# 2043235208842284268_8553571503          NaN      1.641868e+09
# 2060257853995512713_8553571503          NaN      1.641868e+09
# ...                                     ...               ...
# 1918248265532065779_9226952833          NaN      1.641862e+09
# 1915307431740546250_9226952833          NaN      1.641862e+09
# 1915309868421262314_9226952833          NaN      1.641862e+09
# 1915478755821552984_9226952833          NaN      1.641862e+09
# 1913322824232427084_9226952833          NaN      1.641862e+09
#
# [2684 rows x 11 columns]

# %% [markdown]
# # Examples using the data tables

# %% [markdown]
# Example simple statistics:

# %%
def get_average_follower_count(user_table):
    average_follower_count = user_table['follower_count'].mean()
    return average_follower_count

def get_average_following_count(user_table):
    average_following_count = user_table['following_count'].mean()
    return average_following_count

def get_follow_ratio(user_table):
    follow_ratio = user_table['following_count'].divide(loaded_user_table['follower_count']+1)
    follow_ratio_mean = follow_ratio.mean()
    return follow_ratio_mean

def get_follow_ratio_hist(user_table):
    user_table = user_table[user_table['private_status'] == False] #only plot public user histogram 
    follow_ratio = user_table['following_count'].divide(user_table['follower_count']+1)
    std_dev = follow_ratio.std()
    mean = follow_ratio.mean()
    outlier_limit = mean + 3*std_dev
    follow_ratio = follow_ratio[follow_ratio < outlier_limit]
    ax = follow_ratio.plot.hist()
    ax.set_yscale('log')
    ax.set_title('Data on %d public users'%len(follow_ratio))
    ax.set_xlabel('Following Count / (Follower Count + 1)')
    plt.show()

print(f'Average follower count: {get_average_follower_count(loaded_user_table)}')
print(f'Average following count: {get_average_following_count(loaded_user_table)}')
print(f'Average approx follow ratio: {get_follow_ratio(loaded_user_table)}')
get_follow_ratio_hist(loaded_user_table)
# Out:
# Average follower count: 1314.7464319695528
# Average following count: 1106.8575166508087
# Average approx follow ratio: 8.742615751667048

# %% [markdown]
# Example of ranking users based on interaction metric (though this metric is not great)

# %%
"""
Here we calculate an interaction score between 0 (will not interact with us) and 1 (will interact with us).
We want a user who is active, so posts a lot (media_score) and somebody worthy of following (follower_score) 
and tends to follow more users than follow them (confidence_lower_bound)
"""
def get_media_score(user_table):
    """
    Returns a value between 0 (no posts) and 1 (infinite posts)
    """
    media_count = user_table['media_count'].copy()
    media_score = (2/np.pi)*np.arctan(media_count)
    return media_score

def get_follower_score(user_table):
    """
    Returns a value between 0 (no followers) and 1 (infinite followers)
    """
    follower_count = user_table['follower_count']
    follower_score = (2/np.pi)*np.arctan(follower_count/100)
    return follower_score
    
def get_confidence_lower_bound(user_table):
    """
    We model the probability p = num_following / (num_following + num_followers) with a binomial distribution
    and obtain the lower bound for a 95% confidence interval.
    """
    following_count = user_table['following_count']
    follower_count = user_table['follower_count']
    total_follow_count = following_count+follower_count
    p_hat = following_count / total_follow_count
    std_dev_hat = np.sqrt((p_hat * (1-p_hat)) / total_follow_count)
    z_score = 1.96 #for 95% confidence interval
    confidence_lower_bound = p_hat - z_score*std_dev_hat
    
    #make sure confidence interval bound is inside of [0,1]
    confidence_lower_bound.loc[confidence_lower_bound < 0] = 0
    confidence_lower_bound.loc[confidence_lower_bound > 1] = 1
    
    return confidence_lower_bound

def get_interaction_score(user_table):
    media_score = get_media_score(user_table)
    follower_score = get_follower_score(user_table)
    confidence_lower_bound = get_confidence_lower_bound(user_table)
    interaction_score = (media_score+follower_score+confidence_lower_bound)/3
    return interaction_score
    
def rank_for_interactions(user_table):
    user_table = user_table[user_table['private_status'] == False].copy() #only interact with public
    user_table['interaction_score'] = get_interaction_score(user_table)
    user_table.sort_values('interaction_score', ascending=False, inplace=True)
    return user_table

# %%
rank_for_interactions(loaded_user_table)
# Out:
#                                 username  private_status  follower_count  \
# user_id
# 2311292909                    enverimeri           False             798
# 8150292822   realmastercarloscontreiras2           False             831
# 8015715708                   gkgaykeithh           False             834
# 47923979125          tamara_cash_earning           False             867
# 49475334071                  abnal.forat           False             799
# ...                                  ...             ...             ...
# 21544801502         susan.patricia.smith           False               3
# 45184203997               thao5001nguyen           False              14
# 50039716365            thi_duoc_100_diem           False              13
# 6987488244                 ngoc_ngoc7777           False               5
# 38557175293                  gubarlena59           False               8
#
#              following_count  media_count                   full_name  \
# user_id
# 2311292909              7497          974                 Enver Imeri
# 8150292822              7493          295  realmastercarloscontreiras
# 8015715708              7284         1891                Keith B Katz
# 47923979125             7500          222              🌷Tamara Hayes🌷
# 49475334071             7496          145                  Abn Alfrat
# ...                      ...          ...                         ...
# 21544801502                3            0                          Lu
# 45184203997                3            0                 Nguyễn Thảo
# 50039716365                2            0             có cái nịt...?!
# 6987488244                 3            0                ngoc ngoc777
# 38557175293                1            0                   vi_oletta
#
#                                                profile_pic_url  \
# user_id
# 2311292909   https://scontent-lax3-1.cdninstagram.com/v/t51...
# 8150292822   https://scontent-lax3-2.cdninstagram.com/v/t51...
# 8015715708   https://scontent-lax3-2.cdninstagram.com/v/t51...
# 47923979125  https://scontent-lax3-1.cdninstagram.com/v/t51...
# 49475334071  https://scontent-lax3-2.cdninstagram.com/v/t51...
# ...                                                        ...
# 21544801502  https://scontent-lax3-1.cdninstagram.com/v/t51...
# 45184203997  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 50039716365  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 6987488244   https://scontent-lax3-2.cdninstagram.com/v/t51...
# 38557175293  https://instagram.fria4-1.fna.fbcdn.net/v/t51....
#
#                                                       bio_text url_in_bio  \
# user_id
# 2311292909                                           044979001        NaN
# 8150292822                                                 NaN        NaN
# 8015715708   I was gay way before Ellen came out and it was...        NaN
# 47923979125  Get Approved In Minutes📲 I’m Only Here To Help...        NaN
# 49475334071                                                NaN        NaN
# ...                                                        ...        ...
# 21544801502                                                NaN        NaN
# 45184203997                                                NaN        NaN
# 50039716365                                                NaN        NaN
# 6987488244                                                 NaN        NaN
# 38557175293                                                NaN        NaN
#
#              hashtag_following_count  usertags_count  api_request_time  \
# user_id
# 2311292909                        29               0      1.640322e+09
# 8150292822                       467               1      1.640260e+09
# 8015715708                        28               2      1.640343e+09
# 47923979125                        0               0      1.640307e+09
# 49475334071                        3               0      1.640460e+09
# ...                              ...             ...               ...
# 21544801502                        0               0      1.640427e+09
# 45184203997                        0               0      1.640288e+09
# 50039716365                        0               0      1.640288e+09
# 6987488244                         0               0      1.640149e+09
# 38557175293                        0               0      1.640533e+09
#
#              interaction_score
# user_id
# 2311292909            0.939145
# 8150292822            0.938443
# 8015715708            0.938118
# 47923979125           0.937959
# 49475334071           0.937891
# ...                        ...
# 21544801502           0.039670
# 45184203997           0.029517
# 50039716365           0.027433
# 6987488244            0.023775
# 38557175293           0.016940
#
# [4956 rows x 13 columns]
