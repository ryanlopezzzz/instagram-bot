# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
instagram_api_folder = os.path.dirname(os.getcwd())

# %%
api_username = 'cuteanimalzzzz123'

# %%
user_table_filename = os.path.join(instagram_api_folder,'saved_info/%s_collected_user_info_table.csv'%api_username)
if os.path.isfile(user_table_filename):
    loaded_user_table = pd.read_csv(user_table_filename)
    loaded_user_table.set_index('user_id', inplace=True)
else:
    loaded_user_table = None

# %%
loaded_user_table
# Out:
#                             username  private_status  follower_count  \
# user_id
# 421883510                    pmpryor           False             203
# 4267991295   reyesproductionvehicles           False             148
# 47392182295    natalia_mills2020xoxo            True             128
# 4277432176                zidewarren            True            1085
# 1365576031       sable_thomas_buchan            True             458
# ...                              ...             ...             ...
# 4120079014          jamieroberts6222            True             568
# 39612202963              carconnell_           False             419
# 48740245931        jameshatesjameson            True             265
# 8478000530             luca.scharrer           False              47
# 50004795460        cuteanimalzzzz123           False               0
#
#              following_count  media_count                  full_name  \
# user_id
# 421883510                457           12                Peggy Pryor
# 4267991295               287            8  Reyes Production Vehicles
# 47392182295             1007           36              natalie mills
# 4277432176               944          204                Warren Zide
# 1365576031               738          255                      Sable
# ...                      ...          ...                        ...
# 4120079014              1943           87              Jamie Roberts
# 39612202963              582            0           Carley Elizabeth
# 48740245931             1578           26                      James
# 8478000530                41            2              Luca Scharrer
# 50004795460                2            1               Cute Animals
#
#                                                profile_pic_url  \
# user_id
# 421883510    https://scontent-lax3-1.cdninstagram.com/v/t51...
# 4267991295   https://scontent-lax3-1.cdninstagram.com/v/t51...
# 47392182295  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 4277432176   https://scontent-lax3-2.cdninstagram.com/v/t51...
# 1365576031   https://scontent-lax3-2.cdninstagram.com/v/t51...
# ...                                                        ...
# 4120079014   https://scontent-lax3-1.cdninstagram.com/v/t51...
# 39612202963  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 48740245931  https://scontent-lax3-2.cdninstagram.com/v/t51...
# 8478000530   https://scontent-lax3-2.cdninstagram.com/v/t51...
# 50004795460  https://scontent-lax3-2.cdninstagram.com/v/t51...
#
#                                                       bio_text  \
# user_id
# 421883510                                  AVON Leadership Rep
# 4267991295   High-quality, affordable production vehicle re...
# 47392182295         Leaving a bit of sparkle everywhere I go ✨
# 4277432176   Produced the American Pie and Final Destinatio...
# 1365576031   Respiratory Therapist 💪🏻\nMarried to Logan Buc...
# ...                                                        ...
# 4120079014                           Senior RHS class of 2022.
# 39612202963                                                NaN
# 48740245931                       spam, love following people.
# 8478000530   4th year CCS physics student at UCSB. Interest...
# 50004795460                       I post cute animal photos! 🥰
#
#                                       url_in_bio  hashtag_following_count  \
# user_id
# 421883510         http://www.youravon.com/ppryor                        8
# 4267991295   http://reyesproductionvehicles.com/                        1
# 47392182295                                  NaN                        1
# 4277432176                                   NaN                        4
# 1365576031                                   NaN                        1
# ...                                          ...                      ...
# 4120079014                                   NaN                        1
# 39612202963                                  NaN                        0
# 48740245931                                  NaN                        0
# 8478000530                                   NaN                        1
# 50004795460                                  NaN                        0
#
#              usertags_count  api_request_time
# user_id
# 421883510                 1      1.640205e+09
# 4267991295                2      1.640205e+09
# 47392182295               0      1.640205e+09
# 4277432176                0      1.640205e+09
# 1365576031                0      1.640205e+09
# ...                     ...               ...
# 4120079014                0      1.639391e+09
# 39612202963               1      1.639391e+09
# 48740245931               0      1.639391e+09
# 8478000530               12      1.639386e+09
# 50004795460               0      1.639386e+09
#
# [824 rows x 12 columns]

# %%
def get_average_follower_count(user_table):
    average_follower_count = user_table['follower_count'].mean()
    return average_follower_count

get_average_follower_count(loaded_user_table)
# Out:
# 590.254854368932

# %%
def get_average_following_count(user_table):
    average_following_count = user_table['following_count'].mean()
    return average_following_count

get_average_following_count(loaded_user_table)
# Out:
# 1046.625

# %%
def get_follow_ratio(user_table):
    follow_ratio = user_table['following_count'].divide(loaded_user_table['follower_count']+1)
    follow_ratio_mean = follow_ratio.mean()
    return follow_ratio_mean

get_follow_ratio(loaded_user_table)
# Out:
# 8.63792575853634

# %%
def get_follow_ratio_hist(user_table):
    follow_ratio = user_table['following_count'].divide(user_table['follower_count']+1)
    std_dev = follow_ratio.std()
    mean = follow_ratio.mean()
    outlier_limit = mean + 2*std_dev
    follow_ratio = follow_ratio[follow_ratio < outlier_limit]
    ax = follow_ratio.plot.hist(bins=20)
    ax.set_yscale('log')
    ax.set_title('Data on %d users'%len(follow_ratio))
    ax.set_xlabel('Following Count / (Follower Count + 1)')
    plt.show()
    
get_follow_ratio_hist(loaded_user_table)

# %%
def get_sorted_follow_ratio_names(user_table):
    user_table = user_table.set_index('username')
    follow_ratio_column = user_table['following_count'].divide(user_table['follower_count']+1)
    sorted_follow_ratio = follow_ratio_column.sort_values(ascending=False)
    return sorted_follow_ratio
    
get_sorted_follow_ratio_names(loaded_user_table)
# Out:
# username
# sensorytheory      1250.000000
# quinomii            834.000000
# panggyanin          327.000000
# k1tt3nb4byy         220.000000
# senija_3383         206.000000
#                       ...
# thevenicewhaler       0.153477
# santehmsk777          0.139892
# _.alice.__            0.123077
# alisaaa.rgb           0.110306
# kiri.li               0.003411
# Length: 824, dtype: float64
